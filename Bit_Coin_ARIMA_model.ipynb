# %% [markdown]
# # Bit-Coin Prices using Yahoo-Finance

# %%
import yfinance as yf

# %%
df = yf.download('BTC-USD')
# Out:
# [*********************100%%**********************]  1 of 1 completed

# %%
# print(type(df));
df
# Out:
#                     Open          High           Low         Close  \
# Date
# 2014-09-17    465.864014    468.174011    452.421997    457.334015
# 2014-09-18    456.859985    456.859985    413.104004    424.440002
# 2014-09-19    424.102997    427.834991    384.532013    394.795990
# 2014-09-20    394.673004    423.295990    389.882996    408.903992
# 2014-09-21    408.084991    412.425995    393.181000    398.821014
# ...                  ...           ...           ...           ...
# 2023-11-15  35548.113281  37964.894531  35383.781250  37880.582031
# 2023-11-16  37879.980469  37934.625000  35545.472656  36154.769531
# 2023-11-17  36164.824219  36704.484375  35901.234375  36596.683594
# 2023-11-18  36625.371094  36839.281250  36233.312500  36585.703125
# 2023-11-19  36585.765625  36705.937500  36428.953125  36519.093750
#
#                Adj Close       Volume
# Date
# 2014-09-17    457.334015     21056800
# 2014-09-18    424.440002     34483200
# 2014-09-19    394.795990     37919700
# 2014-09-20    408.903992     36863600
# 2014-09-21    398.821014     26580100
# ...                  ...          ...
# 2023-11-15  37880.582031  27365821679
# 2023-11-16  36154.769531  26007385366
# 2023-11-17  36596.683594  22445028430
# 2023-11-18  36585.703125  11886022717
# 2023-11-19  36519.093750  10960816128
#
# [3351 rows x 6 columns]

# %% [markdown]
# # Imports

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from statsmodels.tsa.arima.model import ARIMA
from sklearn.metrics import mean_absolute_error, mean_squared_error

# %%
# x-axis: df.index--> the first colum is dates and should be treated as indices
# y-axis: df["Adj Close"]--> we are picking the column "Adj Close" only
plt.figure(figsize=(10,4));
plt.plot(df.index, df["Adj Close"], color='blue')
plt.xlabel("Dates");
plt.ylabel("Closing Prices");
plt.grid(True);
plt.show()

# %% [markdown]
# # Test-Train Splitting

# %%
# Train-Test split
# 90-10 split

print(df.shape)
index1 = int(len(df)*0.9);

training_data = df[:index1]["Adj Close"];
testing_data  = df[index1:]["Adj Close"];
print(training_data.shape,"\n",training_data,"\n\n",
      testing_data.shape,"\n",testing_data);
# Out:
# (3351, 6)
# (3015,)
#  Date
# 2014-09-17      457.334015
# 2014-09-18      424.440002
# 2014-09-19      394.795990
# 2014-09-20      408.903992
# 2014-09-21      398.821014
#                   ...
# 2022-12-14    17815.650391
# 2022-12-15    17364.865234
# 2022-12-16    16647.484375
# 2022-12-17    16795.091797
# 2022-12-18    16757.976562
# Name: Adj Close, Length: 3015, dtype: float64
#
#  (336,)
#  Date
# 2022-12-19    16439.679688
# 2022-12-20    16906.304688
# 2022-12-21    16817.535156
# 2022-12-22    16830.341797
# 2022-12-23    16796.953125
#                   ...
# 2023-11-15    37880.582031
# 2023-11-16    36154.769531
# 2023-11-17    36596.683594
# 2023-11-18    36585.703125
# 2023-11-19    36519.093750
# Name: Adj Close, Length: 336, dtype: float64

# %%
plt.figure(figsize=(10,4));
plt.plot(training_data.index, training_data[:index1],
         label= "Training",color="blue");
plt.plot(testing_data.index, testing_data[:index1],
         label= "Testing",color="green");
plt.xlabel("Dates");
plt.ylabel("Closing Prices");
plt.grid(True);
plt.legend(framealpha=1);

# %% [markdown]
# # Simulation-Run

# %%
testing_size        = testing_data.shape[0];
model_predictions   = np.zeros_like(testing_data);
training_data_copy  = np.copy(training_data);

# %%
for i in range(testing_size):
  model     = ARIMA(training_data_copy, order=(4,1,0));
  model_fit = model.fit();
  yhat      = model_fit.forecast();
  # Storing the prediction:
  model_predictions[i]  = yhat;
  # Updating the training_data with actual value for next prediction
  # To continue prediction based on previous ones update training_data_copy
  # with yhat, instead of actual_test_value
  actual_test_value     = np.array([testing_data[i]]);
  training_data_copy    = np.append(training_data_copy,actual_test_value,axis = 0);

print(model_fit.summary());
# Out:
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                 3350
# Model:                 ARIMA(4, 1, 0)   Log Likelihood              -27047.382
# Date:                Sun, 19 Nov 2023   AIC                          54104.763
# Time:                        15:25:17   BIC                          54135.345
# Sample:                             0   HQIC                         54115.702
#                                - 3350
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1         -0.0258      0.009     -2.868      0.004      -0.043      -0.008
# ar.L2          0.0098      0.009      1.128      0.259      -0.007       0.027
# ar.L3          0.0218      0.009      2.348      0.019       0.004       0.040
# ar.L4          0.0308      0.008      3.985      0.000       0.016       0.046
# sigma2      6.067e+05   4904.143    123.716      0.000    5.97e+05    6.16e+05
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.00   Jarque-Bera (JB):             39457.40
# Prob(Q):                              0.97   Prob(JB):                         0.00
# Heteroskedasticity (H):             445.33   Skew:                            -0.21
# Prob(H) (two-sided):                  0.00   Kurtosis:                        19.81
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).

# %% [markdown]
# # Visualization

# %%
plt.figure(figsize=(11,5));
plt.plot(testing_data.index,model_predictions,"--",
         color="red", label="Predicted Price");
plt.plot(testing_data.index,testing_data,
         color="green", label="Actual Price");
plt.legend(framealpha=1);
plt.grid();

# %% [markdown]
# # Conclusion

# %%
# Mean-Absolute-Percentage-Error (MAPE):
MAPE = np.mean( np.abs(model_predictions - testing_data ) / np.abs( testing_data) );
print(f"Mean-Absolute-Percentage-Error:\t{MAPE*100:.2f}%");
print(f"Model-Accuracy:\t{(1-MAPE)*100:.2f}%");
# Out:
# Mean-Absolute-Percentage-Error:	1.46%
# Model-Accuracy:	98.54%
